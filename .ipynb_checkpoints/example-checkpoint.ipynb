# %%
import math
import wall_e

# %%
dh_params = [
     [math.pi/2, 0, 0, 20], # theta, d, alpha, a
     [math.pi, 0, 0, 10],
    ]
end_pos = [20, 20, 0] # qx, qy, qz
vels = [10, 5]
accs = [0, 0]
masses = [5, 7]
dimensions = [[10], [10]] # [[r1], [r2]]
taus_req = [2207, 343]

# %%
bender = wall_e.Robot('bender', 'rr', dh_params) # 'rr' - 2 rotary joints
print(bender)
# Out:
# Robot(name=bender, type=rr)

# %%
# forward kinematics
fk_mat_expr, fk_mat = bender.solve_fk()
wall_e.pprint(fk_mat_expr); print();
wall_e.pprint(fk_mat)
# Out:
# ⎡-sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + cos(θ₀(t))⋅cos(θ₁(t))  sin(α₀)⋅sin(α₁)⋅sin(θ
# ⎢
# ⎢sin(θ₀(t))⋅cos(θ₁(t)) + sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))   -sin(α₀)⋅sin(α₁)⋅cos(
# ⎢
# ⎢                  sin(α₀)⋅sin(θ₁(t))
# ⎢
# ⎣                          0
#
# ₀(t)) - sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t))
#
# θ₀(t)) - sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) + cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t))
#
#       sin(α₀)⋅cos(α₁)⋅cos(θ₁(t)) + sin(α₁)⋅cos(α₀)
#
#                             0
#
#   sin(α₀)⋅sin(θ₀(t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + sin(α₁)
#
#   -sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) + sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) - sin(α₁)⋅cos(α₀
#
#                              -sin(α₀)⋅sin(α₁)⋅cos(θ₁(t)) + cos(α₀)⋅cos(α₁)
#
#                                                    0
#
# ⋅sin(θ₁(t))⋅cos(θ₀(t))   a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + a₁
#
# )⋅cos(θ₀(t))⋅cos(θ₁(t))  a₀⋅sin(θ₀(t)) + a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) + a₁⋅sin(θ₁(
#
#                                                        a₁⋅sin(α₀)⋅sin(θ₁(t)) +
#
#                                                                           1
#
# ⋅cos(θ₀(t))⋅cos(θ₁(t)) + d₁⋅sin(α₀)⋅sin(θ₀(t))⎤
#                                               ⎥
# t))⋅cos(α₀)⋅cos(θ₀(t)) - d₁⋅sin(α₀)⋅cos(θ₀(t))⎥
#                                               ⎥
#  d₀ + d₁⋅cos(α₀)                              ⎥
#                                               ⎥
#                                               ⎦
#
# ⎡-1.83697019872103e-16           1.0           0  -6.12323399573677e-16⎤
# ⎢                                                                      ⎥
# ⎢        -1.0           -1.83697019872103e-16  0          10.0         ⎥
# ⎢                                                                      ⎥
# ⎢          0                      0            1            0          ⎥
# ⎢                                                                      ⎥
# ⎣          0                      0            0            1          ⎦

# %%
# inverse kinematics
thetas, fk_mat = bender.solve_ik(end_pos)
print(thetas, end='\n'*2)
wall_e.pprint(fk_mat)
# Out:
# [1.0214374430529793, 5.560451102459508]
#
# ⎡0.955718905051631  -0.294281114798266  0  20.0000001348467⎤
# ⎢                                                          ⎥
# ⎢0.294281114798266  0.955718905051631   0  20.0000001501889⎥
# ⎢                                                          ⎥
# ⎢        0                  0           1         0        ⎥
# ⎢                                                          ⎥
# ⎣        0                  0           0         1        ⎦

# %%
# inverse dynamics
tau_exprs, taus = bender.solve_id(thetas, vels, accs, masses, dimensions)
for tau_expr, tau in zip(tau_exprs, taus):
    print('tau_expr:')
    wall_e.pprint(tau_expr)
    print(f'tau: {tau}', end='\n'*2)
# Out:
# tau_expr:
#
#
# 117.72⋅a₀⋅cos(θ₀(t)) - 68.67⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 68.67⋅a₁⋅cos(θ
#
#
#
#
#
# ₀(t))⋅cos(θ₁(t)) + 68.67⋅d₁⋅sin(α₀)⋅sin(θ₀(t)) + 2⋅((-sin(θ₀(t))⋅cos(θ₁(t)) -
#
#
#
#
#
# sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(-35.0⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t)) + 35.0⋅a₁⋅cos(α
#
#
#
#
#
# ₀)⋅cos(θ₀(t))⋅cos(θ₁(t)) + 233.333333333333⋅sin(θ₀(t))⋅sin(θ₁(t)) - 233.333333
#
#
#
#
#
# 333333⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅cos(θ₁(t))
#
#
#
#
#
# - 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) - s
#
#
#
#
#
# in(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-sin(
#
#
#
#
#
# θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + cos(θ₀(t))⋅cos(θ₁(t)))⋅(35.0⋅a₁⋅sin(θ₀(t))⋅cos(α₀)
#
#
#
#
#
# ⋅cos(θ₁(t)) + 35.0⋅a₁⋅sin(θ₁(t))⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(
#
#
#
#
#
# α₀)⋅cos(θ₁(t)) - 233.333333333333⋅sin(θ₁(t))⋅cos(θ₀(t))) + (175.0⋅sin(θ₀(t))⋅c
#
#
#
#
#
# os(α₁)⋅cos(θ₁(t)) + 175.0⋅sin(θ₁(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t)))⋅(sin(α₀)⋅sin(
#
#
#
#
#
# α₁)⋅cos(θ₀(t)) + sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅co
#
#
#
#
#
# s(θ₁(t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 175.0⋅sin(α₁)⋅cos(
#
#
#
#
#
# θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅sin(θ₀(t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅co
#
#
#
#
#
# s(θ₁(t)) + sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t))) + (175.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α
#
#
#
#
#
# ₀)⋅cos(α₁) - 175.0⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅sin(α₁)⋅sin(θ₀(t))
#
#
#
#
#
# - sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t))) + (-a
#
#
#
#
#
# ₀⋅sin(θ₀(t)) - a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + d
#
#
#
#
#
# ₁⋅sin(α₀)⋅cos(θ₀(t)))⋅(7⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t)) - 7⋅a₁⋅cos(α₀)⋅cos(θ₀(t))⋅co
#
#
#
#
#
# s(θ₁(t)) - 35.0⋅sin(θ₀(t))⋅sin(θ₁(t)) + 35.0⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) +
#
#
#
#
#
# (a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) +
#
#
#
#
#
#  d₁⋅sin(α₀)⋅sin(θ₀(t)))⋅(-7⋅a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ₁(t))
#
#
#
#
#
# ⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(θ₀(t)))
#
#
#
#
#   d         d
# )⋅──(θ₀(t))⋅──(θ₁(t)) + ((-sin(θ₀(t))⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t
#   dt        dt
#
#
#
#
# )))⋅(-35.0⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 35.0⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) +
#
#
#
#
#
# 233.333333333333⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 233.333333333333⋅cos(θ₀(t))⋅c
#
#
#
#
#
# os(θ₁(t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + 175.0⋅sin(α₁)⋅cos(α₀)⋅cos
#
#
#
#
#
# (θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅sin(θ₀(t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅c
#
#
#
#
#
# os(θ₁(t)) + sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t))) + (-sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) +
#
#
#
#
#
#  cos(θ₀(t))⋅cos(θ₁(t)))⋅(35.0⋅a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅a₁⋅sin(θ₁(t))⋅co
#
#
#
#
#
# s(α₀)⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(θ₁(t)) - 233.333333333333⋅s
#
#
#
#
#
# in(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))) + (175.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - 175.0⋅c
#
#
#
#
#
# os(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) - sin(θ₀(t))
#
#
#
#
#
# ⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t))) + (-175.0⋅sin(α₁)
#
#
#
#
#
# ⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t)))⋅(sin(α₀)
#
#
#
#
#
# ⋅cos(α₁)⋅cos(θ₀(t)) - sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + sin(α₁)⋅cos(α₀)⋅cos(θ₀(t
#
#
#
#
#
# ))⋅cos(θ₁(t))) + (175.0⋅sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) + 175.0⋅sin(θ₁(t
#
#
#
#
#
# ))⋅cos(α₁)⋅cos(θ₀(t)))⋅(sin(α₀)⋅sin(α₁)⋅cos(θ₀(t)) + sin(θ₀(t))⋅sin(θ₁(t))⋅cos
#
#
#
#
#
# (α₁) - cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-a₀⋅sin(θ₀(t)) - a₁⋅sin(θ₀(t)
#
#
#
#
#
# )⋅cos(θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + d₁⋅sin(α₀)⋅cos(θ₀(t)))⋅(7⋅a₁
#
#
#
#
#
# ⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 7⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) - 35.0⋅sin(θ₀(t))⋅
#
#
#
#
#
# sin(θ₁(t))⋅cos(α₀) + 35.0⋅cos(θ₀(t))⋅cos(θ₁(t))) + (a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(
#
#
#
#
#
# t))⋅sin(θ₁(t))⋅cos(α₀) + a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) + d₁⋅sin(α₀)⋅sin(θ₀(t)))⋅(-7
#
#
#
#
#
# ⋅a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t
#
#
#
#                                                                 2
#                                                      ⎛d        ⎞
# ))⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))))⋅⎜──(θ₁(t))⎟  + ((-sin(θ₀(
#                                                      ⎝dt       ⎠
#
#
#
#
# t))⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(35.0⋅a₁⋅sin(θ₀(t))⋅cos(α₀)⋅co
#
#
#
#
#
# s(θ₁(t)) + 35.0⋅a₁⋅sin(θ₁(t))⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(α₀)
#
#
#
#
#
# ⋅cos(θ₁(t)) - 233.333333333333⋅sin(θ₁(t))⋅cos(θ₀(t))) + (175.0⋅sin(α₁)⋅sin(θ₀(
#
#
#
#
#
# t))⋅cos(θ₁(t)) + 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(sin(α₀)⋅sin(θ₀(
#
#
#
#
#
# t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + sin(α₁)⋅sin(θ₁(t))⋅cos(θ
#
#
#
#
#
# ₀(t))) + (-sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + cos(θ₀(t))⋅cos(θ₁(t)))⋅(35.0⋅a₁⋅sin
#
#
#
#
#
# (θ₀(t))⋅sin(θ₁(t)) - 35.0⋅a₁⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)) - 233.333333333333⋅
#
#
#
#
#
# sin(θ₀(t))⋅sin(θ₁(t)) + 233.333333333333⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-17
#
#
#
#
#
# 5.0⋅sin(θ₀(t))⋅cos(α₁)⋅cos(θ₁(t)) - 175.0⋅sin(θ₁(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t)
#
#
#
#
#
# ))⋅(sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) - sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) - sin(θ
#
#
#
#
#
# ₁(t))⋅cos(α₁)⋅cos(θ₀(t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 17
#
#
#
#
#
# 5.0⋅sin(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) - sin(α₁)⋅sin(θ
#
#
#
#
#
# ₀(t))⋅sin(θ₁(t)) + sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (175.0⋅sin(θ₀(t))⋅
#
#
#
#
#
# sin(θ₁(t))⋅cos(α₀)⋅cos(α₁) - 175.0⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₀)⋅sin
#
#
#
#
#
# (α₁)⋅cos(θ₀(t)) + sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅c
#
#
#
#
#
# os(θ₁(t))) + (-a₀⋅sin(θ₀(t)) - a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(α₀
#
#
#
#
#
# )⋅cos(θ₀(t)) + d₁⋅sin(α₀)⋅cos(θ₀(t)))⋅(-7⋅a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - 7
#
#
#
#
#
# ⋅a₁⋅sin(θ₁(t))⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t
#
#
#
#
#
# ))⋅cos(θ₀(t))) + (a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + a₁⋅cos(θ₀
#
#
#
#
#
# (t))⋅cos(θ₁(t)) + d₁⋅sin(α₀)⋅sin(θ₀(t)))⋅(-7⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t)) + 7⋅a₁⋅c
#
#
#
#
#
# os(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅sin(θ₀(t))⋅sin(θ₁(t)) - 35.0⋅cos(α₀)⋅cos(θ
#
#
#
#                      2
#                     d
# ₀(t))⋅cos(θ₁(t))))⋅───(θ₁(t)) + (a₀⋅(-5⋅a₀⋅sin(θ₀(t)) + 50.0⋅sin(θ₀(t)))⋅cos(θ
#                      2
#                    dt
#
#
#
# ₀(t)) - a₀⋅(-5⋅a₀⋅cos(θ₀(t)) + 50.0⋅cos(θ₀(t)))⋅sin(θ₀(t)) + (50.0⋅a₀⋅sin(θ₀(t
#
#
#
#
#
# )) - 666.666666666667⋅sin(θ₀(t)))⋅cos(θ₀(t)) - (50.0⋅a₀⋅cos(θ₀(t)) - 666.66666
#
#
#
#
#
# 6666667⋅cos(θ₀(t)))⋅sin(θ₀(t)) + (-sin(θ₀(t))⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₀)⋅
#
#
#
#
#
# cos(θ₀(t)))⋅(35.0⋅a₀⋅cos(θ₀(t)) - 35.0⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 35.0
#
#
#
#
#
# ⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅d₁⋅sin(α₀)⋅sin(θ₀(t)) + 233.333333333333⋅sin(
#
#
#
#
#
# θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 233.333333333333⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-sin(θ₀
#
#
#
#
#
# (t))⋅sin(θ₁(t))⋅cos(α₀) + cos(θ₀(t))⋅cos(θ₁(t)))⋅(35.0⋅a₀⋅sin(θ₀(t)) + 35.0⋅a₁
#
#
#
#
#
# ⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) - 35.0⋅d₁⋅sin(α
#
#
#
#
#
# ₀)⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(θ₁(t)) - 233.333333333333⋅sin(
#
#
#
#
#
# θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))) + (-175.0⋅sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) + 175.0⋅sin(θ₀
#
#
#
#
#
# (t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) + 175.0⋅sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t)))⋅(sin(α₀
#
#
#
#
#
# )⋅sin(α₁)⋅cos(θ₀(t)) + sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - cos(α₀)⋅cos(α₁)⋅cos(θ₀(
#
#
#
#
#
# t))⋅cos(θ₁(t))) + (sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) - sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos
#
#
#
#
#
# (θ₁(t)) - sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t)))⋅(175.0⋅sin(α₀)⋅sin(α₁)⋅cos(θ₀(t)) + 1
#
#
#
#
#
# 75.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - 175.0⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t
#
#
#
#
#
# ))) + (-175.0⋅sin(α₀)⋅sin(θ₀(t))⋅cos(α₁) - 175.0⋅sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅co
#
#
#
#
#
# s(θ₁(t)) - 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t)))⋅(sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) -
#
#
#
#
#
# sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (sin(
#
#
#
#
#
# α₀)⋅sin(θ₀(t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + sin(α₁)⋅sin(θ
#
#
#
#
#
# ₁(t))⋅cos(θ₀(t)))⋅(175.0⋅sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) - 175.0⋅sin(α₁)⋅sin(θ₀(t))
#
#
#
#
#
# ⋅sin(θ₁(t)) + 175.0⋅sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-a₀⋅sin(θ₀(t)) -
#
#
#
#
#
#  a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + d₁⋅sin(α₀)⋅cos(
#
#
#
#
#
# θ₀(t)))⋅(-7⋅a₀⋅cos(θ₀(t)) + 7⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 7⋅a₁⋅cos(θ₀(t
#
#
#
#
#
# ))⋅cos(θ₁(t)) - 7⋅d₁⋅sin(α₀)⋅sin(θ₀(t)) - 35.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) +
#
#
#
#
#
#  35.0⋅cos(θ₀(t))⋅cos(θ₁(t))) + (a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α
#
#
#
#
#
# ₀) + a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) + d₁⋅sin(α₀)⋅sin(θ₀(t)))⋅(-7⋅a₀⋅sin(θ₀(t)) - 7⋅a
#
#
#
#
#
# ₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + 7⋅d₁⋅sin(α₀)⋅co
#
#
#
#
#                                                                              ⎛
# s(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))))⋅⎜
#                                                                              ⎝
#
#
#           2
# d        ⎞    ⎛
# ──(θ₀(t))⎟  + ⎝-a₀⋅(-5⋅a₀⋅sin(θ₀(t)) + 50.0⋅sin(θ₀(t)))⋅sin(θ₀(t)) + a₀⋅(5⋅a₀⋅
# dt       ⎠
#
#
#
#
# cos(θ₀(t)) - 50.0⋅cos(θ₀(t)))⋅cos(θ₀(t)) - (50.0⋅a₀⋅sin(θ₀(t)) - 666.666666666
#
#
#
#
#
# 667⋅sin(θ₀(t)))⋅sin(θ₀(t)) + (-50.0⋅a₀⋅cos(θ₀(t)) + 666.666666666667⋅cos(θ₀(t)
#
#
#
#
#
# ))⋅cos(θ₀(t)) + (-sin(θ₀(t))⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(35.0
#
#
#
#
#
# ⋅a₀⋅sin(θ₀(t)) + 35.0⋅a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅a₁⋅sin(θ₁(t))⋅cos(α₀)⋅co
#
#
#
#
#
# s(θ₀(t)) - 35.0⋅d₁⋅sin(α₀)⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(θ₁(t))
#
#
#
#
#
#  - 233.333333333333⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))) + (-sin(θ₀(t))⋅sin(θ₁(t))⋅c
#
#
#
#
#
# os(α₀) + cos(θ₀(t))⋅cos(θ₁(t)))⋅(-35.0⋅a₀⋅cos(θ₀(t)) + 35.0⋅a₁⋅sin(θ₀(t))⋅sin(
#
#
#
#
#
# θ₁(t))⋅cos(α₀) - 35.0⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) - 35.0⋅d₁⋅sin(α₀)⋅sin(θ₀(t)) -
#
#
#
#
#
# 233.333333333333⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 233.333333333333⋅cos(θ₀(t))⋅c
#
#
#
#
#
# os(θ₁(t))) + (sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) - sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t
#
#
#
#
#
# )) - sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t)))⋅(175.0⋅sin(α₀)⋅sin(α₁)⋅sin(θ₀(t)) - 175.0⋅
#
#
#
#
#
# sin(θ₀(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₁(t)) - 175.0⋅sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t))) +
#
#
#
#
#
#  (sin(α₀)⋅sin(α₁)⋅cos(θ₀(t)) + sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - cos(α₀)⋅cos(α₁)
#
#
#
#
#
# ⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(175.0⋅sin(α₀)⋅sin(α₁)⋅cos(θ₀(t)) + 175.0⋅sin(θ₀(t))⋅s
#
#
#
#
#
# in(θ₁(t))⋅cos(α₁) - 175.0⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (sin(α₀)⋅si
#
#
#
#
#
# n(θ₀(t))⋅cos(α₁) + sin(α₁)⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + sin(α₁)⋅sin(θ₁(t))⋅
#
#
#
#
#
# cos(θ₀(t)))⋅(175.0⋅sin(α₀)⋅sin(θ₀(t))⋅cos(α₁) + 175.0⋅sin(α₁)⋅sin(θ₀(t))⋅cos(α
#
#
#
#
#
# ₀)⋅cos(θ₁(t)) + 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t))) + (sin(α₀)⋅cos(α₁)⋅cos(θ₀
#
#
#
#
#
# (t)) - sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅
#
#
#
#
#
# (175.0⋅sin(α₀)⋅cos(α₁)⋅cos(θ₀(t)) - 175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + 175.
#
#
#
#
#
# 0⋅sin(α₁)⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-a₀⋅sin(θ₀(t)) - a₁⋅sin(θ₀(t))⋅cos
#
#
#
#
#
# (θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + d₁⋅sin(α₀)⋅cos(θ₀(t)))⋅(-7⋅a₀⋅sin
#
#
#
#
#
# (θ₀(t)) - 7⋅a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + 7⋅
#
#
#
#
#
# d₁⋅sin(α₀)⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(α₀)⋅c
#
#
#
#
#
# os(θ₀(t))) + (a₀⋅cos(θ₀(t)) - a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + a₁⋅cos(θ₀(t))
#
#
#
# ...
#
#
#
#  + a₁⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(-7⋅a₁⋅sin(θ₀(t))⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ
#
#
#
#
#
# ₁(t))⋅cos(α₀)⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(α₀
#
#
#
#
#
# )⋅cos(θ₀(t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t)) + 175.0⋅sin(α₁)⋅cos(α₀)⋅
#
#
#
#
#
# cos(θ₀(t))⋅cos(θ₁(t)))⋅(sin(α₁)⋅sin(θ₀(t))⋅cos(θ₁(t)) + sin(α₁)⋅sin(θ₁(t))⋅cos
#
#
#
#
#
# (α₀)⋅cos(θ₀(t))) + (175.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₁) - 175.0⋅cos(α₀)⋅cos(α₁
#
#
#
#
#
# )⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(-sin(θ₀(t))⋅cos(α₁)⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(α₀)⋅
#
#
#
#
#
# cos(α₁)⋅cos(θ₀(t))) + (-sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - sin(θ₁(t))⋅cos(θ₀(t)))
#
#
#
#
#
# ⋅(-35.0⋅a₁⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 35.0⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) + 233
#
#
#
#
#
# .333333333333⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 233.333333333333⋅cos(θ₀(t))⋅cos(
#
#
#
#
#
# θ₁(t))) + (-a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - a₁⋅sin(θ₁(t))⋅cos(θ₀(t)))⋅(7⋅a₁
#
#
#
#
#
# ⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) - 7⋅a₁⋅cos(θ₀(t))⋅cos(θ₁(t)) - 35.0⋅sin(θ₀(t))⋅
#
#
#
#
#
# sin(θ₁(t))⋅cos(α₀) + 35.0⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁
#
#
#
#
#
# (t))⋅cos(α₀) + sin(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅cos(α
#
#
#
#
#
# ₀)⋅cos(θ₁(t)) - 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(θ₀(t))) + (sin(θ₀(t))⋅sin(θ₁(t))⋅
#
#
#
#
#
# cos(α₀)⋅cos(α₁) - cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(175.0⋅sin(θ₀(t))⋅cos(α₀)⋅cos
#
#
#
#
#                                                                   2        2
# (α₁)⋅cos(θ₁(t)) + 175.0⋅sin(θ₁(t))⋅cos(α₁)⋅cos(θ₀(t))) + 175.0⋅sin (α₀)⋅sin (α
#
#
#
#
#                                     2                   2               ⎞ ⎛d
# ₁)⋅sin(θ₁(t))⋅cos(θ₁(t)) + 175.0⋅sin (α₀)⋅sin(θ₁(t))⋅cos (α₁)⋅cos(θ₁(t))⎠⋅⎜──(
#                                                                           ⎝dt
#
#
#        2
#       ⎞    ⎛
# θ₁(t))⎟  + ⎝a₁⋅(7⋅a₁⋅sin(α₀)⋅cos(θ₁(t)) - 35.0⋅sin(α₀)⋅cos(θ₁(t)))⋅sin(α₀)⋅cos
#       ⎠
#
#
#
#
# (θ₁(t)) + (-sin(θ₀(t))⋅sin(θ₁(t)) + cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(35.0⋅a₁⋅si
#
#
#
#
#
# n(θ₀(t))⋅sin(θ₁(t)) - 35.0⋅a₁⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)) - 233.333333333333
#
#
#
#
#
# ⋅sin(θ₀(t))⋅sin(θ₁(t)) + 233.333333333333⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (-3
#
#
#
#
#
# 5.0⋅a₁⋅sin(α₀)⋅cos(θ₁(t)) + 233.333333333333⋅sin(α₀)⋅cos(θ₁(t)))⋅sin(α₀)⋅cos(θ
#
#
#
#
#
# ₁(t)) + (-a₁⋅sin(θ₀(t))⋅sin(θ₁(t)) + a₁⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)))⋅(-7⋅a₁⋅
#
#
#
#
#
# sin(θ₀(t))⋅sin(θ₁(t)) + 7⋅a₁⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t)) + 35.0⋅sin(θ₀(t))⋅s
#
#
#
#
#
# in(θ₁(t)) - 35.0⋅cos(α₀)⋅cos(θ₀(t))⋅cos(θ₁(t))) + (sin(α₁)⋅sin(θ₀(t))⋅cos(θ₁(t
#
#
#
#
#
# )) + sin(α₁)⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t)))⋅(175.0⋅sin(α₁)⋅sin(θ₀(t))⋅cos(θ₁(t
#
#
#
#
#
# )) + 175.0⋅sin(α₁)⋅sin(θ₁(t))⋅cos(α₀)⋅cos(θ₀(t))) + (-sin(θ₀(t))⋅cos(α₀)⋅cos(θ
#
#
#
#
#
# ₁(t)) - sin(θ₁(t))⋅cos(θ₀(t)))⋅(35.0⋅a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + 35.0⋅a
#
#
#
#
#
# ₁⋅sin(θ₁(t))⋅cos(θ₀(t)) - 233.333333333333⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - 233
#
#
#
#
#
# .333333333333⋅sin(θ₁(t))⋅cos(θ₀(t))) + (-175.0⋅sin(θ₀(t))⋅cos(α₁)⋅cos(θ₁(t)) -
#
#
#
#
#
#  175.0⋅sin(θ₁(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t)))⋅(-sin(θ₀(t))⋅cos(α₁)⋅cos(θ₁(t))
#
#
#
#
#
# - sin(θ₁(t))⋅cos(α₀)⋅cos(α₁)⋅cos(θ₀(t))) + (-a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t))
#
#
#
#
#
# - a₁⋅sin(θ₁(t))⋅cos(θ₀(t)))⋅(-7⋅a₁⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) - 7⋅a₁⋅sin(θ₁
#
#
#
#
#
# (t))⋅cos(θ₀(t)) + 35.0⋅sin(θ₀(t))⋅cos(α₀)⋅cos(θ₁(t)) + 35.0⋅sin(θ₁(t))⋅cos(θ₀(
#
#
#
#
#
# t))) + (-175.0⋅sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + 175.0⋅sin(α₁)⋅cos(θ₀(t)
#
#
#
#
#
# )⋅cos(θ₁(t)))⋅(-sin(α₁)⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀) + sin(α₁)⋅cos(θ₀(t))⋅cos
#
#
#
#
#
# (θ₁(t))) + (sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀)⋅cos(α₁) - cos(α₁)⋅cos(θ₀(t))⋅cos(θ₁(
#
#
#
#
#
# t)))⋅(175.0⋅sin(θ₀(t))⋅sin(θ₁(t))⋅cos(α₀)⋅cos(α₁) - 175.0⋅cos(α₁)⋅cos(θ₀(t))⋅c
#
#
#
#
#                       2        2        2                   2        2
# os(θ₁(t))) + 175.0⋅sin (α₀)⋅sin (α₁)⋅sin (θ₁(t)) + 175.0⋅sin (α₀)⋅sin (θ₁(t))⋅
#
#
#
#             2
#    2    ⎞  d
# cos (α₁)⎠⋅───(θ₁(t)) + 343.35⋅sin(θ₀(t))⋅sin(θ₁(t)) - 343.35⋅cos(α₀)⋅cos(θ₀(t)
#             2
#           dt
#
#
#
# )⋅cos(θ₁(t))
#
#
# tau: -45972.4995951806

# %%
# forward dynamics
'''
computation of forward dynamics takes a lot of time, i suggest you to create a new class and 
override the solve_id() method and rewrite the output tau expressions in numpy like shown below 
as sympy is super slow at numeric computation

class Bender(Robot):
    def solve_id():
        # write the inverse dynamics logic here in numpy
'''
optim_vals, taus = bender.solve_fd(masses, dimensions, taus_req)
print(optim_vals)
print(taus)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-65b3e91bd180> in <module>
#       9         # write the inverse dynamics logic here in numpy
#      10 '''
# ---> 11 optim_vals, taus = bender.solve_fd(masses, dimensions, taus_req)
#      12 print(optim_vals)
#      13 print(taus)
#
# D:\robotics\wall_e\wall_e\core.py in solve_fd(self, masses, dimensions, taus_req, tol)
#     354             tol = 3e-4
#     355
# --> 356         result = minimize(cost_fn, initial_guess, tol=tol)
#     357         optim_vals = result.x
#     358         # optim_vals = initial_guess
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     602         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     603     elif meth == 'bfgs':
# --> 604         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     605     elif meth == 'newton-cg':
#     606         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1007     else:
#    1008         grad_calls, myfprime = wrap_function(fprime, args)
# -> 1009     gfk = myfprime(x0)
#    1010     k = 0
#    1011     N = len(x0)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\optimize.py in approx_fprime(xk, f, epsilon, *args)
#     763
#     764     """
# --> 765     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     766
#     767
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     695         ei[k] = 1.0
#     696         d = epsilon * ei
# --> 697         df = (f(*((xk + d,) + args)) - f0) / d[k]
#     698         if not np.isscalar(df):
#     699             try:
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# D:\robotics\wall_e\wall_e\core.py in _cost_fn_fd(self, initial_guess, masses, dimensions, taus_req)
#     340     def _cost_fn_fd(self, initial_guess, masses, dimensions, taus_req):
#     341         thetas, lengths, vels, accs = self._get_vals(initial_guess)
# --> 342         taus = self.solve_id(thetas, vels, accs, masses, dimensions, lengths)[1]
#     343         cost = 0
#     344         for tr, t in zip(taus_req, taus):
#
# D:\robotics\wall_e\wall_e\core.py in solve_id(self, thetas, vels, accs, masses, dimensions, lengths)
#     314         taus = []
#     315         for tau_expr in self.tau_exprs:
# --> 316             tau = tau_expr.subs(d_alpha_dict).subs(acc_dict).subs(vel_dict).subs(theta_dict).subs(a_dict)
#     317             taus.append(tau)
#     318         return self.tau_exprs, taus
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in subs(self, *args, **kwargs)
#    1000             rv = self
#    1001             for old, new in sequence:
# -> 1002                 rv = rv._subs(old, new, **kwargs)
#    1003                 if not isinstance(rv, Basic):
#    1004                     break
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
# -> 1116             rv = fallback(self, old, new)
#    1117         return rv
#    1118
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1086                 if not hasattr(arg, '_eval_subs'):
#    1087                     continue
# -> 1088                 arg = arg._subs(old, new, **hints)
#    1089                 if not _aresame(arg, args[i]):
#    1090                     hit = True
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
# -> 1116             rv = fallback(self, old, new)
#    1117         return rv
#    1118
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1086                 if not hasattr(arg, '_eval_subs'):
#    1087                     continue
# -> 1088                 arg = arg._subs(old, new, **hints)
#    1089                 if not _aresame(arg, args[i]):
#    1090                     hit = True
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
# -> 1116             rv = fallback(self, old, new)
#    1117         return rv
#    1118
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1086                 if not hasattr(arg, '_eval_subs'):
#    1087                     continue
# -> 1088                 arg = arg._subs(old, new, **hints)
#    1089                 if not _aresame(arg, args[i]):
#    1090                     hit = True
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
# -> 1116             rv = fallback(self, old, new)
#    1117         return rv
#    1118
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1086                 if not hasattr(arg, '_eval_subs'):
#    1087                     continue
# -> 1088                 arg = arg._subs(old, new, **hints)
#    1089                 if not _aresame(arg, args[i]):
#    1090                     hit = True
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
# -> 1116             rv = fallback(self, old, new)
#    1117         return rv
#    1118
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1086                 if not hasattr(arg, '_eval_subs'):
#    1087                     continue
# -> 1088                 arg = arg._subs(old, new, **hints)
#    1089                 if not _aresame(arg, args[i]):
#    1090                     hit = True
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\harin kumar\appdata\local\programs\python\python37\lib\site-packages\sympy\core\expr.py in __hash__(self)
#     102         return expr.class_key(), args, exp, coeff
#     103
# --> 104     def __hash__(self):
#     105         # hash cannot be cached using cache_it because infinite recurrence
#     106         # occurs as hash is needed for setting cache dictionary keys
#
# KeyboardInterrupt:
